# %% [markdown]
# <a href="https://colab.research.google.com/github/gaboitec/Challenge-TelcomX-ONE-pandas-matplotlib/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import pandas as pd

# %%
datos = pd.read_json('TelecomX_Data.json')

# %%
datos.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# ...

# %% [markdown]
# #🔧 Transformación

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos['customer'].head()
# Out:
# 0    {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2    {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3    {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4    {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# Name: customer, dtype: object

# %%
df_normalizado = pd.json_normalize(datos['account'])
df_normalizado.head()
# Out:
#          Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0        One year              Yes      Mailed check             65.6
# 1  Month-to-month               No      Mailed check             59.9
# 2  Month-to-month              Yes  Electronic check             73.9
# 3  Month-to-month              Yes  Electronic check             98.0
# 4  Month-to-month              Yes      Mailed check             83.9
#
#   Charges.Total
# 0         593.3
# 1         542.4
# 2        280.85
# 3       1237.85
# 4         267.4

# %%
df_datos = pd.json_normalize(datos.to_dict(orient='records'))
df_datos.head()
# Out:
#    customerID Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0  0002-ORFBO    No          Female                       0              Yes
# 1  0003-MKNFE    No            Male                       0               No
# 2  0004-TLHLJ   Yes            Male                       0               No
# 3  0011-IGKFF   Yes            Male                       1              Yes
# 4  0013-EXCHZ   Yes          Female                       1              Yes
#
#   customer.Dependents  customer.tenure phone.PhoneService phone.MultipleLines  \
# 0                 Yes                9                Yes                  No
# 1                  No                9                Yes                 Yes
# 2                  No                4                Yes                  No
# 3                  No               13                Yes                  No
# 4                  No                3                Yes                  No
#
# ...

# %%
df_datos = df_datos.drop(labels=['customerID', 'account.Charges.Total'], axis=1, inplace=False)

# %%
df_datos
# Out:
#      Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0       No          Female                       0              Yes
# 1       No            Male                       0               No
# 2      Yes            Male                       0               No
# 3      Yes            Male                       1              Yes
# 4      Yes          Female                       1              Yes
# ...    ...             ...                     ...              ...
# 7262    No          Female                       0               No
# 7263   Yes            Male                       0              Yes
# 7264    No            Male                       0               No
# 7265    No            Male                       0              Yes
# 7266    No            Male                       0              Yes
#
#      customer.Dependents  customer.tenure phone.PhoneService  \
# 0                    Yes                9                Yes
# ...

# %%
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      7267 non-null   object
#  1   customer.gender            7267 non-null   object
#  2   customer.SeniorCitizen     7267 non-null   int64
#  3   customer.Partner           7267 non-null   object
#  4   customer.Dependents        7267 non-null   object
#  5   customer.tenure            7267 non-null   int64
#  6   phone.PhoneService         7267 non-null   object
#  7   phone.MultipleLines        7267 non-null   object
#  8   internet.InternetService   7267 non-null   object
#  9   internet.OnlineSecurity    7267 non-null   object
#  10  internet.OnlineBackup      7267 non-null   object
#  11  internet.DeviceProtection  7267 non-null   object
#  12  internet.TechSupport       7267 non-null   object
# ...

# %%
df_datos.duplicated().sum()
# Out:
# np.int64(27)

# %%
df_datos = df_datos.drop_duplicates()

# %%
df_datos.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_datos.isnull().sum()
# Out:
# Churn                        0
# customer.gender              0
# customer.SeniorCitizen       0
# customer.Partner             0
# customer.Dependents          0
# customer.tenure              0
# phone.PhoneService           0
# phone.MultipleLines          0
# internet.InternetService     0
# internet.OnlineSecurity      0
# internet.OnlineBackup        0
# internet.DeviceProtection    0
# internet.TechSupport         0
# internet.StreamingTV         0
# internet.StreamingMovies     0
# account.Contract             0
# account.PaperlessBilling     0
# account.PaymentMethod        0
# account.Charges.Monthly      0
# dtype: int64

# %%
import numpy as np

df_datos['customer.SeniorCitizen'] = df_datos['customer.SeniorCitizen'].astype(np.int64)
# Out:
# /tmp/ipykernel_561/2058098495.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['customer.SeniorCitizen'] = df_datos['customer.SeniorCitizen'].astype(np.int64)

# %%
df_datos['customer.tenure'] = df_datos['customer.tenure'].astype(np.int64)
# Out:
# /tmp/ipykernel_561/1926120638.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['customer.tenure'] = df_datos['customer.tenure'].astype(np.int64)

# %%
df_datos
# Out:
#      Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0       No          Female                       0              Yes
# 1       No            Male                       0               No
# 2      Yes            Male                       0               No
# 3      Yes            Male                       1              Yes
# 4      Yes          Female                       1              Yes
# ...    ...             ...                     ...              ...
# 7262    No          Female                       0               No
# 7263   Yes            Male                       0              Yes
# 7264    No            Male                       0               No
# 7265    No            Male                       0              Yes
# 7266    No            Male                       0              Yes
#
#      customer.Dependents  customer.tenure phone.PhoneService  \
# 0                    Yes                9                Yes
# ...

# %%
df_datos['account.Charges.Monthly'] = df_datos['account.Charges.Monthly'].astype(np.float64)
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7240 entries, 0 to 7266
# Data columns (total 19 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Churn                      7240 non-null   object
#  1   customer.gender            7240 non-null   object
#  2   customer.SeniorCitizen     7240 non-null   int64
#  3   customer.Partner           7240 non-null   object
#  4   customer.Dependents        7240 non-null   object
#  5   customer.tenure            7240 non-null   int64
#  6   phone.PhoneService         7240 non-null   object
#  7   phone.MultipleLines        7240 non-null   object
#  8   internet.InternetService   7240 non-null   object
#  9   internet.OnlineSecurity    7240 non-null   object
#  10  internet.OnlineBackup      7240 non-null   object
#  11  internet.DeviceProtection  7240 non-null   object
#  12  internet.TechSupport       7240 non-null   object
# ...

# %%
df_datos['account.Contract']
# Out:
# 0             One year
# 1       Month-to-month
# 2       Month-to-month
# 3       Month-to-month
# 4       Month-to-month
#              ...
# 7262          One year
# 7263    Month-to-month
# 7264    Month-to-month
# 7265          Two year
# 7266          Two year
# Name: account.Contract, Length: 7240, dtype: object

# %%
df_datos['cuentas_diarias'] = (df_datos['account.Charges.Monthly'] * 12) / 365
df_datos
# Out:
# /tmp/ipykernel_561/418097354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['cuentas_diarias'] = (df_datos['account.Charges.Monthly'] * 12) / 365
#      Churn customer.gender  customer.SeniorCitizen customer.Partner  \
# 0       No          Female                       0              Yes
# 1       No            Male                       0               No
# 2      Yes            Male                       0               No
# 3      Yes            Male                       1              Yes
# 4      Yes          Female                       1              Yes
# ...    ...             ...                     ...              ...
# 7262    No          Female                       0               No
# ...

# %%
df_datos.columns = df_datos.columns.str.lower().str.replace('.', '_')
df_datos
# Out:
#      churn customer_gender  customer_seniorcitizen customer_partner  \
# 0       No          Female                       0              Yes
# 1       No            Male                       0               No
# 2      Yes            Male                       0               No
# 3      Yes            Male                       1              Yes
# 4      Yes          Female                       1              Yes
# ...    ...             ...                     ...              ...
# 7262    No          Female                       0               No
# 7263   Yes            Male                       0              Yes
# 7264    No            Male                       0               No
# 7265    No            Male                       0              Yes
# 7266    No            Male                       0              Yes
#
#      customer_dependents  customer_tenure phone_phoneservice  \
# 0                    Yes                9                Yes
# ...

# %%
cols_bol = ['churn', 'customer_partner', 'customer_dependents', 'phone_phoneservice', 'phone_multiplelines', 'internet_onlinesecurity', 'internet_onlinebackup', 'internet_deviceprotection', 'internet_techsupport', 'internet_streamingtv', 'internet_streamingmovies', 'account_paperlessbilling']
df_datos[cols_bol] = df_datos[cols_bol].replace({"Yes":1, "No":0, "No phone service":0, "No internet service":0})
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7240 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7240 non-null   object
#  1   customer_gender            7240 non-null   object
#  2   customer_seniorcitizen     7240 non-null   int64
#  3   customer_partner           7240 non-null   int64
#  4   customer_dependents        7240 non-null   int64
#  5   customer_tenure            7240 non-null   int64
#  6   phone_phoneservice         7240 non-null   int64
#  7   phone_multiplelines        7240 non-null   int64
#  8   internet_internetservice   7240 non-null   object
#  9   internet_onlinesecurity    7240 non-null   int64
#  10  internet_onlinebackup      7240 non-null   int64
#  11  internet_deviceprotection  7240 non-null   int64
#  12  internet_techsupport       7240 non-null   int64
# ...

# %%
df_datos['churn'] = df_datos['churn'].replace({"":None})
df_datos = df_datos.dropna()
df_datos.groupby('churn').count()
# Out:
# /tmp/ipykernel_561/1244733081.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['churn'] = df_datos['churn'].replace({"":None})
#        customer_gender  customer_seniorcitizen  customer_partner  \
# churn
# 0                 5159                    5159              5159
# 1                 1857                    1857              1857
#
#        customer_dependents  customer_tenure  phone_phoneservice  \
# churn
# 0                     5159             5159                5159
# 1                     1857             1857                1857
#
#        phone_multiplelines  internet_internetservice  internet_onlinesecurity  \
# churn
# 0                     5159                      5159                     5159
# ...

# %%
df_datos['churn'] = df_datos['churn'].astype(np.int64)
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7016 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7016 non-null   int64
#  1   customer_gender            7016 non-null   object
#  2   customer_seniorcitizen     7016 non-null   int64
#  3   customer_partner           7016 non-null   int64
#  4   customer_dependents        7016 non-null   int64
#  5   customer_tenure            7016 non-null   int64
#  6   phone_phoneservice         7016 non-null   int64
#  7   phone_multiplelines        7016 non-null   int64
#  8   internet_internetservice   7016 non-null   object
#  9   internet_onlinesecurity    7016 non-null   int64
#  10  internet_onlinebackup      7016 non-null   int64
#  11  internet_deviceprotection  7016 non-null   int64
#  12  internet_techsupport       7016 non-null   int64
# ...

# %%
df_datos['customer_gender'].value_counts()
# Out:
# customer_gender
# Male      3537
# Female    3479
# Name: count, dtype: int64

# %%
df_datos['internet_internetservice'].value_counts()
# Out:
# internet_internetservice
# Fiber optic    3089
# DSL            2419
# No             1508
# Name: count, dtype: int64

# %%
df_datos['account_contract'].value_counts()
# Out:
# account_contract
# Month-to-month    3851
# Two year          1692
# One year          1473
# Name: count, dtype: int64

# %%
df_datos['account_paymentmethod'].value_counts()
# Out:
# account_paymentmethod
# Electronic check             2359
# Mailed check                 1593
# Bank transfer (automatic)    1544
# Credit card (automatic)      1520
# Name: count, dtype: int64

# %%
df_datos.sample(10)
# Out:
#       churn customer_gender  customer_seniorcitizen  customer_partner  \
# 3890      0          Female                       0                 1
# 2628      0          Female                       0                 0
# 3667      0          Female                       0                 1
# 5163      0          Female                       0                 1
# 2611      0          Female                       0                 0
# 6283      1          Female                       0                 1
# 7147      0            Male                       0                 1
# 6646      0            Male                       0                 1
# 3615      0          Female                       0                 0
# 1653      0            Male                       0                 1
#
#       customer_dependents  customer_tenure  phone_phoneservice  \
# 3890                    1               58                   1
# 2628                    0               54                   1
# ...

# %%
df_datos['account_contract'] = df_datos['account_contract'].replace('[^a-zA-Z0-9]', ' ', regex=True)
df_datos['account_paymentmethod'] = df_datos['account_paymentmethod'].replace('[^a-zA-Z0-9]', ' ', regex=True)
# Out:
# /tmp/ipykernel_561/3881517981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['account_contract'] = df_datos['account_contract'].replace('[^a-zA-Z0-9]', ' ', regex=True)
# /tmp/ipykernel_561/3881517981.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_datos['account_paymentmethod'] = df_datos['account_paymentmethod'].replace('[^a-zA-Z0-9]', ' ', regex=True)

# %%
df_datos.sample(10)
# Out:
#       churn customer_gender  customer_seniorcitizen  customer_partner  \
# 3731      0          Female                       0                 1
# 536       0            Male                       0                 0
# 5017      0            Male                       1                 0
# 6628      0          Female                       0                 0
# 1276      0          Female                       0                 0
# 3869      0          Female                       0                 1
# 6431      1          Female                       0                 1
# 5318      0            Male                       0                 1
# 4292      0            Male                       0                 0
# 4991      0            Male                       0                 1
#
#       customer_dependents  customer_tenure  phone_phoneservice  \
# 3731                    0               59                   1
# 536                     0               46                   0
# ...

# %%
for col in ['customer_gender', 'internet_internetservice', 'account_contract', 'account_paymentmethod']:
    df_datos[col] = df_datos[col].astype(str).str.strip()
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7016 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7016 non-null   int64
#  1   customer_gender            7016 non-null   object
#  2   customer_seniorcitizen     7016 non-null   int64
#  3   customer_partner           7016 non-null   int64
#  4   customer_dependents        7016 non-null   int64
#  5   customer_tenure            7016 non-null   int64
#  6   phone_phoneservice         7016 non-null   int64
#  7   phone_multiplelines        7016 non-null   int64
#  8   internet_internetservice   7016 non-null   object
#  9   internet_onlinesecurity    7016 non-null   int64
#  10  internet_onlinebackup      7016 non-null   int64
#  11  internet_deviceprotection  7016 non-null   int64
#  12  internet_techsupport       7016 non-null   int64
# ...

# %%
# Convert specified object columns to pandas StringDtype
for col in ['customer_gender', 'internet_internetservice', 'account_contract', 'account_paymentmethod']:
    df_datos[col] = df_datos[col].astype(pd.StringDtype())

# Display the info again to see the updated dtypes
df_datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7016 entries, 0 to 7266
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   churn                      7016 non-null   int64
#  1   customer_gender            7016 non-null   string
#  2   customer_seniorcitizen     7016 non-null   int64
#  3   customer_partner           7016 non-null   int64
#  4   customer_dependents        7016 non-null   int64
#  5   customer_tenure            7016 non-null   int64
#  6   phone_phoneservice         7016 non-null   int64
#  7   phone_multiplelines        7016 non-null   int64
#  8   internet_internetservice   7016 non-null   string
#  9   internet_onlinesecurity    7016 non-null   int64
#  10  internet_onlinebackup      7016 non-null   int64
#  11  internet_deviceprotection  7016 non-null   int64
#  12  internet_techsupport       7016 non-null   int64
# ...

# %% [markdown]
# #📊 Carga y análisis

# %%
df_datos.describe()
# Out:
#              churn  customer_seniorcitizen  customer_partner  \
# count  7016.000000             7016.000000       7016.000000
# mean      0.264681                0.162628          0.484464
# std       0.441194                0.369052          0.499794
# min       0.000000                0.000000          0.000000
# 25%       0.000000                0.000000          0.000000
# 50%       0.000000                0.000000          0.000000
# 75%       1.000000                0.000000          1.000000
# max       1.000000                1.000000          1.000000
#
#        customer_dependents  customer_tenure  phone_phoneservice  \
# count          7016.000000      7016.000000         7016.000000
# mean              0.300599        32.462087            0.902794
# std               0.458551        24.526687            0.296260
# min               0.000000         0.000000            0.000000
# 25%               0.000000         9.000000            1.000000
# ...

# %% [markdown]
# #📄Informe final
